# %% [markdown]
# # K-vecinos más cercanos (KNN)
# ## Datos de clientes bancarios:

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer


clientes = pd.read_csv("Movie_Ratings.csv")
clientes
# Out:
#                peliculas  Patrick C  Heather  Bryan  Patrick T  Thomas  aaron  \
# 0                  Alien        NaN      NaN    2.0        NaN     5.0    4.0
# 1                 Avatar        4.0      5.0    5.0        4.0     2.0    NaN
# 2           Blade Runner        5.0      NaN    NaN        NaN     5.0    4.0
# 3             Braveheart        4.0      NaN    5.0        NaN     4.0    4.0
# 4              Dodgeball        5.0      4.0    3.0        2.0     4.0    NaN
# 5            Forest Gump        4.0      5.0    4.0        3.0     3.0    NaN
# 6              Gladiator        NaN      5.0    5.0        NaN     4.0    4.0
# 7                   Jaws        NaN      5.0    4.0        NaN     4.0    NaN
# 8                 Kazaam        2.0      NaN    3.0        5.0     2.0    NaN
# 9      Lord of the Rings        4.0      4.0    3.0        2.0     NaN    5.0
# 10     Napolean Dynamite        3.0      4.0    1.0        1.0     5.0    1.0
# 11            Old School        3.0      NaN    4.0        5.0     5.0    NaN
# 12           Pootie Tang        NaN      NaN    1.0        1.0     NaN    NaN
# 13          Pulp Fiction        NaN      NaN    4.0        NaN     4.0    3.0
# 14              Scarface        NaN      4.0    NaN        NaN     5.0    4.0
# 15  Shawshank Redemption        5.0      NaN    5.0        NaN     NaN    5.0
# 16     Snakes on a Plane        4.0      1.0    2.0        NaN     4.0    NaN
# 17             Spiderman        4.0      3.0    4.0        4.0     5.0    3.0
# 18             Star Wars        5.0      5.0    4.0        5.0     5.0    3.0
# 19       The Dark Knight        4.0      5.0    5.0        4.0     4.0    NaN
# 20         The Happening        1.0      NaN    NaN        NaN     1.0    NaN
# 21            The Matrix        3.0      4.0    3.0        5.0     4.0    4.0
# 22             Toy Story        4.0      3.0    3.0        4.0     4.0    5.0
# 23               Village        NaN      2.0    3.0        1.0     1.0    NaN
# 24          You Got Mail        1.0      NaN    1.0        1.0     1.0    3.0
#
#     vanessa  greg  brian  ...  Zak  Matt  Chris.1  Josh  Amy  Valerie  Gary  \
# 0       NaN   NaN    4.0  ...  NaN   NaN      4.0   3.0  NaN      NaN   2.0
# 1       4.0   3.0    NaN  ...  5.0   NaN      NaN   4.0  3.0      2.0   1.0
# 2       NaN   1.0    5.0  ...  NaN   NaN      3.0   NaN  3.0      3.0   1.0
# 3       3.0   4.0    4.0  ...  5.0   NaN      4.0   NaN  3.0      4.0   5.0
# 4       4.0   5.0    3.0  ...  3.0   NaN      3.0   NaN  4.0      3.0   4.0
# 5       4.0   5.0    5.0  ...  5.0   4.0      5.0   4.0  4.0      5.0   4.0
# 6       4.0   5.0    5.0  ...  5.0   NaN      3.0   4.0  NaN      3.0   3.0
# 7       2.0   3.0    3.0  ...  NaN   NaN      5.0   5.0  3.0      2.0   4.0
# 8       NaN   NaN    1.0  ...  1.0   NaN      NaN   NaN  1.0      1.0   1.0
# 9       2.0   3.0    5.0  ...  4.0   1.0      4.0   NaN  NaN      5.0   3.0
# 10      4.0   4.0    4.0  ...  1.0   3.0      1.0   NaN  2.0      5.0   4.0
# 11      3.0   5.0    4.0  ...  5.0   NaN      4.0   NaN  3.0      3.0   5.0
# 12      1.0   NaN    1.0  ...  NaN   NaN      1.0   NaN  NaN      NaN   NaN
# 13      NaN   4.0    5.0  ...  5.0   NaN      5.0   NaN  4.0      3.0   3.0
# 14      4.0   4.0    NaN  ...  3.0   NaN      2.0   NaN  NaN      4.0   3.0
# 15      NaN   5.0    5.0  ...  NaN   NaN      4.0   NaN  2.0      5.0   5.0
# 16      NaN   NaN    3.0  ...  NaN   1.0      3.0   NaN  2.0      1.0   2.0
# 17      NaN   4.0    4.0  ...  3.0   3.0      2.0   4.0  3.0      5.0   2.0
# 18      3.0   5.0    5.0  ...  5.0   NaN      5.0   5.0  NaN      5.0   5.0
# 19      NaN   4.0    4.0  ...  5.0   NaN      4.0   4.0  4.0      5.0   NaN
# 20      NaN   NaN    2.0  ...  1.0   NaN      NaN   NaN  NaN      1.0   NaN
# 21      4.0   4.0    5.0  ...  5.0   NaN      2.0   5.0  5.0      4.0   2.0
# 22      4.0   5.0    5.0  ...  4.0   4.0      4.0   4.0  4.0      5.0   4.0
# 23      2.0   NaN    4.0  ...  4.0   NaN      1.0   4.0  NaN      2.0   NaN
# 24      NaN   NaN    3.0  ...  2.0   NaN      1.0   NaN  2.0      2.0   1.0
#
#     Stephen  Jessica  Jeff
# 0       5.0      NaN   4.0
# 1       4.0      NaN   4.0
# 2       NaN      NaN   5.0
# 3       5.0      NaN   4.0
# 4       3.0      NaN   3.0
# 5       1.0      4.0   4.0
# 6       4.0      NaN   4.0
# 7       2.0      3.0   5.0
# 8       NaN      1.0   1.0
# 9       5.0      3.0   3.0
# 10      2.0      2.0   3.0
# 11      NaN      2.0   3.0
# 12      NaN      NaN   5.0
# 13      3.0      4.0   3.0
# 14      NaN      NaN   NaN
# 15      NaN      NaN   NaN
# 16      NaN      2.0   1.0
# 17      3.0      3.0   4.0
# 18      5.0      5.0   5.0
# 19      4.0      5.0   5.0
# 20      1.0      NaN   NaN
# 21      5.0      NaN   5.0
# 22      4.0      5.0   5.0
# 23      2.0      NaN   2.0
# 24      2.0      NaN   2.0
#
# [25 rows x 26 columns]

# %%
datos = clientes[["Patrick C","Heather","Bryan","Patrick T","Thomas","aaron","vanessa","greg","brian","ben","Katherine","Jonathan","Zwe","Erin","Chris","Zak","Matt","Chris","Josh","Amy","Valerie","Gary","Stephen","Jessica","Jeff"
]]
clase = clientes["likee"]

escalador = preprocessing.MinMaxScaler()

datos = escalador.fit_transform(datos)

clasificador = KNeighborsClassifier(n_neighbors=2)

clasificador.fit(datos, clase)

edad = 20
fantasia = 0
terror = 0
misterio = 1
drama = 0

#Escalar los datos del nuevo solicitante
solicitante = escalador.transform([[edad, fantasia, terror, misterio, drama]])

#Calcular clase y probabilidades
print("Clase:", clasificador.predict(solicitante))
print("Probabilidades por clase",
      clasificador.predict_proba(solicitante))


resultado = clasificador.predict(solicitante)

if resultado == 1:
    print("Al nuevo solicitante le gustaría la película.")
else:
    print("Al nuevo solicitante no le gustaría la película.")
# Out:
# [[4.         4.         3.         2.         3.76470588 5.
#   2.         3.         5.         2.         4.         4.
#   3.         4.         3.         4.         1.         4.
#   4.33333333 3.28571429 5.         3.         5.         3.
#   3.        ]
#  [3.73333333 4.30769231 4.         3.         4.         3.
#   3.30769231 4.         5.         4.         4.18181818 5.
#   4.         3.63636364 5.         5.         3.         5.
#   4.33333333 4.         3.         3.         3.         4.
#   3.        ]
#  [4.         5.         5.         4.         2.         3.69230769
#   4.         3.         4.05555556 3.         5.         4.
#   4.         4.         1.         5.         3.         3.22222222
#   4.         3.         2.         1.         4.         3.77777778
#   4.        ]
#  [4.         3.         3.         4.         4.         5.
#   4.         5.         5.         5.         5.         5.
#   4.         5.         3.         4.         4.         4.
#   4.         4.         5.         4.         4.         5.
#   5.        ]
#  [4.         5.         4.         3.         3.         3.69230769
#   4.         5.         5.         5.         5.         5.
#   5.         5.         3.         5.         4.         5.
#   4.         4.         5.         4.         1.         4.
#   4.        ]
#  [5.         4.30769231 3.52941176 3.         5.         4.
#   3.30769231 1.         5.         5.         4.18181818 4.125
#   3.33333333 3.63636364 5.         3.8125     3.         3.
#   4.33333333 3.         3.         1.         3.3125     3.77777778
#   5.        ]
#  [3.73333333 4.30769231 1.         1.         3.76470588 3.69230769
#   1.         4.         1.         1.         4.18181818 4.125
#   2.         3.63636364 3.         3.8125     3.         1.
#   4.33333333 3.28571429 3.73684211 3.17647059 3.3125     3.77777778
#   5.        ]
#  [5.         4.30769231 5.         3.         3.76470588 5.
#   3.30769231 5.         5.         5.         4.18181818 4.125
#   4.         3.63636364 4.         3.8125     3.         4.
#   4.33333333 2.         5.         5.         3.3125     3.77777778
#   4.05882353]
#  [4.         4.30769231 5.         3.         4.         4.
#   3.         4.         4.         3.88235294 3.         4.
#   3.         4.         2.         5.         3.         4.
#   4.33333333 3.         4.         5.         5.         3.77777778
#   4.        ]
#  [5.         4.         3.         2.         4.         3.69230769
#   4.         5.         3.         4.         5.         5.
#   3.         3.         3.         3.         3.         3.
#   4.33333333 4.         3.         4.         3.         3.77777778
#   3.        ]
#  [1.         4.30769231 3.52941176 3.         1.         3.69230769
#   3.30769231 4.         2.         3.88235294 4.18181818 4.125
#   1.         3.63636364 1.         1.         3.         3.22222222
#   4.33333333 3.28571429 1.         3.17647059 1.         3.77777778
#   4.05882353]
#  [4.         3.         4.         4.         5.         3.
#   3.30769231 4.         4.         4.         5.         3.
#   4.         3.         2.         3.         3.         2.
#   4.         3.         5.         2.         3.         3.
#   4.        ]
#  [3.         4.         3.         5.         4.         4.
#   4.         4.         5.         4.         4.         5.
#   4.         4.         4.         5.         3.         2.
#   5.         5.         4.         2.         5.         3.77777778
#   5.        ]
#  [5.         5.         4.         5.         5.         3.
#   3.         5.         5.         5.         5.         5.
#   4.         3.         4.         5.         3.         5.
#   5.         3.28571429 5.         5.         5.         5.
#   5.        ]
#  [1.         4.30769231 1.         1.         1.         3.
#   3.30769231 4.         3.         3.88235294 4.18181818 2.
#   2.         3.63636364 2.89473684 2.         3.         1.
#   4.33333333 2.         2.         1.         2.         3.77777778
#   2.        ]
#  [3.73333333 5.         4.         3.         4.         3.69230769
#   2.         3.         3.         1.         4.18181818 3.
#   2.         3.         2.         3.8125     3.         5.
#   5.         3.         2.         4.         2.         3.
#   5.        ]
#  [3.         4.         1.         1.         5.         1.
#   4.         4.         4.         4.         2.         3.
#   3.         2.         1.         1.         3.         1.
#   4.33333333 2.         5.         4.         2.         2.
#   3.        ]
#  [3.73333333 4.         3.52941176 3.         5.         4.
#   4.         4.         4.05555556 4.         4.18181818 4.
#   3.33333333 3.63636364 3.         3.         3.         2.
#   4.33333333 3.28571429 4.         3.         3.3125     3.77777778
#   4.05882353]
#  [4.         5.         5.         4.         4.         3.69230769
#   3.30769231 4.         4.         5.         4.18181818 5.
#   5.         3.63636364 3.         5.         3.         4.
#   4.         4.         5.         3.17647059 4.         5.
#   5.        ]
#  [3.73333333 5.         5.         3.         4.         4.
#   4.         5.         5.         5.         3.         4.
#   3.         3.63636364 3.         5.         3.         3.
#   4.         3.28571429 3.         3.         4.         3.77777778
#   4.        ]]
# [[2.         4.30769231 3.         5.         2.         3.69230769
#   3.30769231 4.         1.         3.88235294 2.         2.
#   2.         1.         1.         1.         3.         3.22222222
#   4.33333333 1.         1.         1.         3.3125     1.
#   1.        ]
#  [4.         1.         2.         3.         4.         3.69230769
#   3.30769231 4.         3.         2.         4.18181818 4.125
#   1.         3.63636364 3.         3.8125     1.         3.
#   4.33333333 2.         1.         2.         3.3125     2.
#   1.        ]
#  [3.73333333 4.30769231 2.         3.         5.         4.
#   3.30769231 4.         4.         3.88235294 4.18181818 4.125
#   3.33333333 3.63636364 2.         3.8125     3.         4.
#   3.         3.28571429 3.73684211 2.         5.         3.77777778
#   4.        ]
#  [3.73333333 2.         3.         1.         1.         3.69230769
#   2.         4.         4.         3.         4.18181818 4.125
#   4.         3.63636364 3.         4.         3.         1.
#   4.         3.28571429 2.         3.17647059 2.         3.77777778
#   2.        ]
#  [3.         4.30769231 4.         5.         5.         3.69230769
#   3.         5.         4.         4.         4.18181818 5.
#   4.         3.63636364 5.         5.         3.         4.
#   4.33333333 3.         3.         5.         3.3125     2.
#   3.        ]]
# Precisión del modelo KNN: 0.0
# [[-1.61868930e+00  0.00000000e+00 -4.17006445e-01  1.75411604e+00
#   -1.51716521e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   -2.73601368e+00 -3.64027691e-16 -2.86038777e+00 -2.56284643e+00
#   -1.33333333e+00 -4.03322756e+00 -1.66856319e+00 -2.20843103e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00 -3.10226694e+00
#   -2.17441931e+00 -1.76330477e+00  0.00000000e+00 -4.01869018e+00
#   -3.53897115e+00]]
# Película predicha: ['Napolean Dynamite']
